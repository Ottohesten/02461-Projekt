# %%
import numpy as np
# import pygame
from HelperClasses import Board
from SnakeGameClass_4Directions import Point, SnakeGame, Direction
from Agent_4_directions import train
from collections import deque
# Out:
# pygame 2.1.2 (SDL 2.0.18, Python 3.9.7)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
game = SnakeGame()

# %%
# train()
# Out:
# tensor(72.6789, grad_fn=<MseLossBackward0>)
# tensor(3566.2029, grad_fn=<MseLossBackward0>)
# tensor(58.9146, grad_fn=<MseLossBackward0>)
# tensor(1890.6908, grad_fn=<MseLossBackward0>)
# Collision
# tensor(904.5485, grad_fn=<MseLossBackward0>)
# tensor(347.0515, grad_fn=<MseLossBackward0>)
# Game: 1	 Score: 0	 Record: 0
# tensor(70.3292, grad_fn=<MseLossBackward0>)
# tensor(106.8005, grad_fn=<MseLossBackward0>)
# Collision
# tensor(51.8894, grad_fn=<MseLossBackward0>)
# tensor(313.3028, grad_fn=<MseLossBackward0>)
# Game: 2	 Score: 0	 Record: 0
# tensor(55.3750, grad_fn=<MseLossBackward0>)
# tensor(131.5124, grad_fn=<MseLossBackward0>)
# tensor(4.3113, grad_fn=<MseLossBackward0>)
# tensor(61.5468, grad_fn=<MseLossBackward0>)
# tensor(61.1621, grad_fn=<MseLossBackward0>)
# tensor(10.5672, grad_fn=<MseLossBackward0>)
# tensor(111.4545, grad_fn=<MseLossBackward0>)
# tensor(12.8939, grad_fn=<MseLossBackward0>)
# tensor(65.1646, grad_fn=<MseLossBackward0>)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\otto\OneDrive - Danmarks Tekniske Universitet\DTU\Kurser\02461 Introduktion til intelligente systemer\02461-Projekt\tests_4directions.ipynb Cell 4 in <module>
# ----> <a href='vscode-notebook-cell:/c%3A/Users/otto/OneDrive%20-%20Danmarks%20Tekniske%20Universitet/DTU/Kurser/02461%20Introduktion%20til%20intelligente%20systemer/02461-Projekt/tests_4directions.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> x
#
# NameError: name 'x' is not defined
